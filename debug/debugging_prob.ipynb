# %%
import pickle

# %%
with open('../data_and_models/probabilistic_search_results_paths25_steps5.pkl', 'rb') as f:
    prob_25 = pickle.load(f)
with open('../data_and_models/probabilistic_search_results_paths50_steps5.pkl', 'rb') as f:
    prob_50 = pickle.load(f)
with open('../data_and_models/probabilistic_search_results_paths100_steps5.pkl', 'rb') as f:
    prob_100 = pickle.load(f)
with open('../data_and_models/probabilistic_search_results_paths200_steps5.pkl', 'rb') as f:
    prob_200 = pickle.load(f)
with open('../data_and_models/probabilistic_search_results_paths400_steps5.pkl', 'rb') as f:
    prob_400 = pickle.load(f)
with open('../data_and_models/probabilistic_search_results_paths800_steps5.pkl', 'rb') as f:
    prob_800 = pickle.load(f)
with open('../data_and_models/search_results_tree_k4_n5.pkl', 'rb') as f:
    tree_k4_n5 = pickle.load(f)

# %%
print(len(prob_25[prob_25['covered_threshold']==True]))
print(len(prob_50[prob_50['covered_threshold']==True]))
print(len(prob_100[prob_100['covered_threshold']==True]))
print(len(prob_200[prob_200['covered_threshold']==True]))
print(len(prob_400[prob_400['covered_threshold']==True]))
print(len(prob_800[prob_800['covered_threshold']==True]))
print(len(tree_k4_n5[tree_k4_n5['covered_threshold']==True]))
# Out:
# 1
# 9
# 22
# 32
# 74
# 94
# 13512
