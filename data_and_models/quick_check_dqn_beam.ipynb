# %%
import pickle

# %%
with open('dqn_search_results_CVCL_0292_k4_n5.pkl', 'rb') as f:
    dqn_out = pickle.load(f)
with open('search_results_beam_k4_n5_debug.pkl', 'rb') as f:
    beam_out = pickle.load(f)

# %%
beam_out = beam_out[(beam_out['target_cl'] == 'CVCL_0292') & (beam_out['covered_threshold'] == True)].copy()
dqn_out = dqn_out[dqn_out['covered_threshold'] == True].copy()

# %%
beam_out
# Out:
#        search_id type_of_search  n_steps  k n_paths  beta  blend  threshold  \
# 211           54    k_path_beam        5  4    None  None      2        0.5
# 446          101    k_path_beam        5  4    None  None      2        0.5
# 447          101    k_path_beam        5  4    None  None      2        0.5
# 448          101    k_path_beam        5  4    None  None      2        0.5
# 449          101    k_path_beam        5  4    None  None      2        0.5
# ...          ...            ...      ... ..     ...   ...    ...        ...
# 10413       2217    k_path_beam        5  4    None  None      2        0.5
# 10414       2217    k_path_beam        5  4    None  None      2        0.5
# 10415       2217    k_path_beam        5  4    None  None      2        0.5
# 10416       2217    k_path_beam        5  4    None  None      2        0.5
# 10417       2217    k_path_beam        5  4    None  None      2        0.5
#
#       starting_cl  target_cl  ... step  path_type  is_best_at_step  \
# 211     CVCL_0028  CVCL_0292  ...  5.0  threshold             True
# 446     CVCL_0069  CVCL_0292  ...  5.0  threshold             True
# 447     CVCL_0069  CVCL_0292  ...  5.0  threshold            False
# 448     CVCL_0069  CVCL_0292  ...  5.0  threshold            False
# 449     CVCL_0069  CVCL_0292  ...  5.0  threshold            False
# ...           ...        ...  ...  ...        ...              ...
# 10413   CVCL_C466  CVCL_0292  ...  4.0  threshold            False
# 10414   CVCL_C466  CVCL_0292  ...  5.0  threshold             True
# 10415   CVCL_C466  CVCL_0292  ...  5.0  threshold            False
# 10416   CVCL_C466  CVCL_0292  ...  5.0  threshold            False
# 10417   CVCL_C466  CVCL_0292  ...  5.0  threshold            False
#
#        is_success  covered_threshold  \
# 211         False               True
# 446         False               True
# 447         False               True
# 448         False               True
# 449         False               True
# ...           ...                ...
# 10413       False               True
# 10414       False               True
# 10415       False               True
# 10416       False               True
# 10417       False               True
#
#                                             end_position  \
# 211    [-1.0052910311157153, -0.19204741419877805, 1....
# 446    [-0.9961060374022226, 0.17049027994322752, 1.2...
# 447    [-0.9961060374022226, 0.17049027994322752, 1.2...
# 448    [-0.9962255104547879, 0.17256664737956504, 1.2...
# 449    [-1.2338843913993864, 0.0933060909670041, 1.50...
# ...                                                  ...
# 10413  [-0.019135803558902695, 0.4606565497840799, 0....
# 10414  [-0.3438086411393649, 0.49015154563351865, 1.4...
# 10415  [-0.33942132820298665, 0.48791017484818594, 1....
# 10416  [-0.33567282601505877, 0.48584783286041544, 1....
# 10417  [-0.3313047806104696, 0.48402269805553627, 1.4...
#
#                                            drug_sequence  \
# 211    [[('Alpelisib', 5.0, 'uM')], [('Doxorubicin (h...
# 446    [[('Capmatinib', 5.0, 'uM')], [('olaparib', 5....
# 447    [[('olaparib', 5.0, 'uM')], [('Capmatinib', 5....
# 448    [[('Capmatinib', 5.0, 'uM')], [('olaparib', 5....
# 449    [[('Capmatinib', 5.0, 'uM')], [('olaparib', 5....
# ...                                                  ...
# 10413  [[('Bortezomib', 5.0, 'uM')], [('Brimonidine',...
# 10414  [[('Bortezomib', 5.0, 'uM')], [('Drospirenone'...
# 10415  [[('Bortezomib', 5.0, 'uM')], [('Drospirenone'...
# 10416  [[('Bortezomib', 5.0, 'uM')], [('Filgotinib', ...
# 10417  [[('Bortezomib', 5.0, 'uM')], [('Brimonidine',...
#
#                                           genes_targeted  \
# 211    [(pik3ca,), (top2a, top2b, top1), (cckbr,), (d...
# 446    [(met,), (parp3, parp2, parp1), (ptgs2,), (pgr...
# 447    [(parp3, parp2, parp1), (met,), (ptgs2,), (pgr...
# 448    [(met,), (parp3, parp2, parp1), (pgr, nr3c2, a...
# 449    [(met,), (parp3, parp2, parp1), (ptgs2,), (pgr...
# ...                                                  ...
# 10413  [(psmb1, psmd8, psmb7, psmd3, psma3, psmb3, ps...
# 10414  [(psmb1, psmd8, psmb7, psmd3, psma3, psmb3, ps...
# 10415  [(psmb1, psmd8, psmb7, psmd3, psma3, psmb3, ps...
# 10416  [(psmb1, psmd8, psmb7, psmd3, psma3, psmb3, ps...
# 10417  [(psmb1, psmd8, psmb7, psmd3, psma3, psmb3, ps...
#
#                                                cell_path final_distance
# 211    [[CVCL_0028, None], [CVCL_0028, None], [CVCL_0...       2.810529
# 446    [[CVCL_0069, None], [CVCL_0069, None], [CVCL_1...       3.363243
# 447    [[CVCL_0069, None], [CVCL_0069, None], [CVCL_1...       3.363243
# 448    [[CVCL_0069, None], [CVCL_0069, None], [CVCL_1...       3.364161
# 449    [[CVCL_0069, None], [CVCL_0069, None], [CVCL_1...       3.375819
# ...                                                  ...            ...
# 10413  [[CVCL_C466, None], [CVCL_1716, CVCL_0292], [C...       3.908267
# 10414  [[CVCL_C466, None], [CVCL_1716, CVCL_0292], [C...       3.805223
# 10415  [[CVCL_C466, None], [CVCL_1716, CVCL_0292], [C...       3.810613
# 10416  [[CVCL_C466, None], [CVCL_1716, CVCL_0292], [C...       3.811684
# 10417  [[CVCL_C466, None], [CVCL_1716, CVCL_0292], [C...       3.817779
#
# [201 rows x 24 columns]

# %%
dqn_out[dqn_out['step'] < 5]
# Out:
#      search_id   type_of_search  n_steps  k n_paths  beta  blend  threshold  \
# 28          10  dqn_guided_beam        5  4    None  None      2        0.5
# 29          10  dqn_guided_beam        5  4    None  None      2        0.5
# 90          17  dqn_guided_beam        5  4    None  None      2        0.5
# 174         32  dqn_guided_beam        5  4    None  None      2        0.5
# 175         32  dqn_guided_beam        5  4    None  None      2        0.5
#
#     starting_cl  target_cl  ... step  path_type  is_best_at_step  is_success  \
# 28    CVCL_0334  CVCL_0292  ...    4  threshold            False       False
# 29    CVCL_0334  CVCL_0292  ...    4  threshold             True       False
# 90    CVCL_0459  CVCL_0292  ...    4  threshold             True       False
# 174   CVCL_1517  CVCL_0292  ...    4  threshold            False       False
# 175   CVCL_1517  CVCL_0292  ...    4  threshold             True       False
#
#      covered_threshold                                       end_position  \
# 28                True  [-1.4429295010076126, 0.2953660403174846, 1.18...
# 29                True  [-1.341523777949026, 0.2968937155561514, 1.118...
# 90                True  [-0.47989506857952957, -0.9958886765823323, 2....
# 174               True  [-1.149769813501382, 0.3078953180606885, 2.159...
# 175               True  [-1.2063404939762514, 0.09660378217484061, 2.0...
#
#                                          drug_sequence  \
# 28   [[('(S)-Crizotinib', 5.0, 'uM')], [('Irinoteca...
# 29   [[('(S)-Crizotinib', 5.0, 'uM')], [('Volaserti...
# 90   [[('Rucaparib (phosphate)', 5.0, 'uM')], [('Af...
# 174  [[('olaparib', 5.0, 'uM')], [('Adenosine', 5.0...
# 175  [[('olaparib', 5.0, 'uM')], [('Adenosine', 5.0...
#
#                                         genes_targeted  \
# 28   [(eml4, alk, ros1, npm1, met), (top1mt, top1),...
# 29   [(eml4, alk, ros1, npm1, met), (plk1,), (cdk4,...
# 90   [(parp3, parp2, parp1), (erbb2, erbb4, egfr), ...
# 174  [(parp3, parp2, parp1), (adora1, adora2a, ador...
# 175  [(parp3, parp2, parp1), (adora1, adora2a, ador...
#
#                                              cell_path final_distance
# 28   [[CVCL_0334, None], [CVCL_0334, CVCL_1716], [C...       3.363233
# 29   [[CVCL_0334, None], [CVCL_0334, None], [CVCL_0...       3.331655
# 90   [[CVCL_0459, CVCL_1716], [CVCL_0459, CVCL_1716...       4.341287
# 174  [[CVCL_1517, None], [CVCL_1517, CVCL_1716], [C...       3.651447
# 175  [[CVCL_1517, None], [CVCL_1517, CVCL_1716], [C...       3.556799
#
# [5 rows x 24 columns]
