# %%
import pickle
import pandas as pd

# %%
with open('../data_and_models/search_results_tree_k4_n5.pkl', 'rb') as f:
    search_k5_n5 = pickle.load(f)

# %%
search_k5_n5
# Out:
#        search_id type_of_search  n_steps  k n_paths  beta  blend  threshold  \
# 0              1     k_pathtree        5  4    None  None      2        0.4
# 1              1     k_pathtree        5  4    None  None      2        0.4
# 2              1     k_pathtree        5  4    None  None      2        0.4
# 3              1     k_pathtree        5  4    None  None      2        0.4
# 4              1     k_pathtree        5  4    None  None      2        0.4
# ...          ...            ...      ... ..     ...   ...    ...        ...
# 77037       2254     k_pathtree        5  4    None  None      2        0.4
# 77038       2254     k_pathtree        5  4    None  None      2        0.4
# 77039       2254     k_pathtree        5  4    None  None      2        0.4
# 77040       2254     k_pathtree        5  4    None  None      2        0.4
# 77041       2254     k_pathtree        5  4    None  None      2        0.4
#
# ...

# %%
search_k5_n5[(search_k5_n5['starting_distance'] - search_k5_n5['final_distance'])/search_k5_n5['starting_distance'] > 0.62]
# Out:
#        search_id type_of_search  n_steps  k n_paths  beta  blend  threshold  \
# 28640        901     k_pathtree        5  4    None  None      2        0.4
# 28641        901     k_pathtree        5  4    None  None      2        0.4
# 28642        901     k_pathtree        5  4    None  None      2        0.4
# 28643        901     k_pathtree        5  4    None  None      2        0.4
# 28644        901     k_pathtree        5  4    None  None      2        0.4
# 28645        901     k_pathtree        5  4    None  None      2        0.4
# 28646        901     k_pathtree        5  4    None  None      2        0.4
# 28647        901     k_pathtree        5  4    None  None      2        0.4
# 28648        901     k_pathtree        5  4    None  None      2        0.4
# 28652        901     k_pathtree        5  4    None  None      2        0.4
# 28653        901     k_pathtree        5  4    None  None      2        0.4
# ...

# %%
search_k5_n5[search_k5_n5['path_type'] == 'threshold'][['starting_cl', 'target_cl']].drop_duplicates().shape[0]
# Out:
# 207

# %%
search_k5_n5[search_k5_n5['path_type'] == 'threshold'] ['target_cl'].drop_duplicates().shape[0]
# Out:
# 25

# %%
with open('../data_and_models/probabilistic_search_results_paths300_steps5_b1.0_blend2_thr0.4.pkl', 'rb') as f:
    search_paths300_n5 = pickle.load(f)

# %%
search_paths300_n5
# Out:
#        search_id type_of_search  n_steps     k  n_paths  beta  blend  \
# 0              0  probabilistic        5  None      300   1.0      2
# 1              0  probabilistic        5  None      300   1.0      2
# 2              0  probabilistic        5  None      300   1.0      2
# 3              0  probabilistic        5  None      300   1.0      2
# 4              0  probabilistic        5  None      300   1.0      2
# ...          ...            ...      ...   ...      ...   ...    ...
# 13944       2255  probabilistic        5  None      300   1.0      2
# 13945       2255  probabilistic        5  None      300   1.0      2
# 13946       2255  probabilistic        5  None      300   1.0      2
# 13947       2255  probabilistic        5  None      300   1.0      2
# 13948       2255  probabilistic        5  None      300   1.0      2
#
#       threshold starting_cl  target_cl  ... step     path_type  \
# 0          None   CVCL_0023  CVCL_0028  ...    1  best_at_step
# ...

# %%
search_paths300_n5[(search_paths300_n5['starting_distance'] - search_paths300_n5['final_distance'])/search_paths300_n5['starting_distance'] > 0.57]
# Out:
#       search_id type_of_search  n_steps     k  n_paths  beta  blend threshold  \
# 5224        901  probabilistic        5  None      300   1.0      2      None
# 7769       1230  probabilistic        5  None      300   1.0      2      None
#
#      starting_cl  target_cl  ... step  path_type  is_best_at_step  is_success  \
# 5224   CVCL_0459  CVCL_0292  ...    5  threshold             True       False
# 7769   CVCL_1097  CVCL_0292  ...    4  threshold             True       False
#
#       covered_threshold                                       end_position  \
# 5224               True  [-0.6708116737706488, 0.057514088912868334, 1....
# 7769               True  [-0.6617480816592507, 0.7267932709232893, 1.45...
#
#                                           drug_sequence  \
# 5224  [[('Doxorubicin (hydrochloride)', 5.0, 'uM')],...
# 7769  [[('olaparib', 5.0, 'uM')], [('venetoclax', 5....
#
#                                          genes_targeted  \
# ...

# %%
search_paths300_n5[search_paths300_n5['path_type'] == 'threshold'][['starting_cl', 'target_cl']].drop_duplicates().shape[0]
# Out:
# 64

# %%
search_paths300_n5[search_paths300_n5['path_type'] == 'threshold'] ['target_cl'].drop_duplicates().shape[0]
# Out:
# 10
