# %%
import pandas as pd 
import numpy as np 
import pickle

# %%
with open('../drugs_to_genes/data/simplified_df2.pkl', 'rb') as f:
    drugs_to_genes = pickle.load(f)

# %%
drugs_to_genes
check = drugs_to_genes.dropna()
check
# Out:
#                 compound                     gene_names_gpt2  \
# 8            abemaciclib                        [cdk4, cdk6]
# 9    abiraterone acetate                             cyp17a1
# 14             adenosine  [adora1, adora2a, adora3, adora2b]
# 15              afatinib                       [erbb2, egfr]
# 16             aliskiren                                 ren
# ..                   ...                                 ...
# 346           venetoclax                                bcl2
# 347            verapamil                     [abcb1, cyp3a4]
# 352           vismodegib                 [abcg2, smo, abcb1]
# 354           volasertib                  [plk1, plk3, plk2]
# 358             zileuton                               alox5
#
#                                         gene_names_dtc  \
# 8    [bmp2k, ccnd3, prkcd, aak1, camkk2, cdk16, prk...
# 9                                              cyp17a1
# 14   [adora1, adora2b, adora2a, kmt2a, hspa8, smn2,...
# ...
